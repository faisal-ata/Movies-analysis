# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('top-500-movies.csv')

# %%
df.head()
# Out:
#    rank release_date                                        title  \
# 0     1   2019-04-23                            Avengers: Endgame
# 1     2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2     3   2015-04-22                      Avengers: Age of Ultron
# 3     4   2015-12-16         Star Wars Ep. VII: The Force Awakens
# 4     5   2018-04-25                       Avengers: Infinity War
#
#                                                  url  production_cost  \
# 0         /movie/Avengers-Endgame-(2019)#tab=summary        400000000
# 1  /movie/Pirates-of-the-Caribbean-On-Stranger-Ti...        379000000
# 2          /movie/Avengers-Age-of-Ultron#tab=summary        365000000
# 3  /movie/Star-Wars-Ep-VII-The-Force-Awakens#tab=...        306000000
# 4           /movie/Avengers-Infinity-War#tab=summary        300000000
#
#    domestic_gross  worldwide_gross  opening_weekend   mpaa      genre  \
# 0       858373000       2797800564      357115007.0  PG-13     Action
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   rank             500 non-null    int64
#  1   release_date     499 non-null    object
#  2   title            500 non-null    object
#  3   url              500 non-null    object
#  4   production_cost  500 non-null    int64
#  5   domestic_gross   500 non-null    int64
#  6   worldwide_gross  500 non-null    int64
#  7   opening_weekend  479 non-null    float64
#  8   mpaa             492 non-null    object
#  9   genre            495 non-null    object
#  10  theaters         479 non-null    float64
#  11  runtime          487 non-null    float64
#  12  year             499 non-null    float64
# dtypes: float64(4), int64(4), object(5)
# memory usage: 50.9+ KB

# %%
df2 = df.copy()

# %%
df2
# Out:
#      rank release_date                                        title  \
# 0       1   2019-04-23                            Avengers: Endgame
# 1       2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2       3   2015-04-22                      Avengers: Age of Ultron
# 3       4   2015-12-16         Star Wars Ep. VII: The Force Awakens
# 4       5   2018-04-25                       Avengers: Infinity War
# ..    ...          ...                                          ...
# 495   496   2013-02-06                       A Good Day to Die Hard
# 496   497   2004-04-09                                    The Alamo
# 497   498   1995-12-22                             Cutthroat Island
# 498   499   2013-12-19              The Secret Life of Walter Mitty
# 499   500   2023-03-09                                           65
#
#                                                    url  production_cost  \
# 0           /movie/Avengers-Endgame-(2019)#tab=summary        400000000
# ...

# %%
df2.head()
# Out:
#    rank release_date                                        title  \
# 0     1   2019-04-23                            Avengers: Endgame
# 1     2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2     3   2015-04-22                      Avengers: Age of Ultron
# 3     4   2015-12-16         Star Wars Ep. VII: The Force Awakens
# 4     5   2018-04-25                       Avengers: Infinity War
#
#                                                  url  production_cost  \
# 0         /movie/Avengers-Endgame-(2019)#tab=summary        400000000
# 1  /movie/Pirates-of-the-Caribbean-On-Stranger-Ti...        379000000
# 2          /movie/Avengers-Age-of-Ultron#tab=summary        365000000
# 3  /movie/Star-Wars-Ep-VII-The-Force-Awakens#tab=...        306000000
# 4           /movie/Avengers-Infinity-War#tab=summary        300000000
#
#    domestic_gross  worldwide_gross  opening_weekend   mpaa      genre  \
# 0       858373000       2797800564      357115007.0  PG-13     Action
# ...

# %%
df2.drop(['rank'], axis =1)
# Out:
#     release_date                                        title  \
# 0     2019-04-23                            Avengers: Endgame
# 1     2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2     2015-04-22                      Avengers: Age of Ultron
# 3     2015-12-16         Star Wars Ep. VII: The Force Awakens
# 4     2018-04-25                       Avengers: Infinity War
# ..           ...                                          ...
# 495   2013-02-06                       A Good Day to Die Hard
# 496   2004-04-09                                    The Alamo
# 497   1995-12-22                             Cutthroat Island
# 498   2013-12-19              The Secret Life of Walter Mitty
# 499   2023-03-09                                           65
#
#                                                    url  production_cost  \
# 0           /movie/Avengers-Endgame-(2019)#tab=summary        400000000
# 1    /movie/Pirates-of-the-Caribbean-On-Stranger-Ti...        379000000
# ...

# %%
df2.drop(['url'],axis=1)
# Out:
#      rank release_date                                        title  \
# 0       1   2019-04-23                            Avengers: Endgame
# 1       2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2       3   2015-04-22                      Avengers: Age of Ultron
# 3       4   2015-12-16         Star Wars Ep. VII: The Force Awakens
# 4       5   2018-04-25                       Avengers: Infinity War
# ..    ...          ...                                          ...
# 495   496   2013-02-06                       A Good Day to Die Hard
# 496   497   2004-04-09                                    The Alamo
# 497   498   1995-12-22                             Cutthroat Island
# 498   499   2013-12-19              The Secret Life of Walter Mitty
# 499   500   2023-03-09                                           65
#
#      production_cost  domestic_gross  worldwide_gross  opening_weekend   mpaa  \
# ...

# %%
df2 = df2.drop(['url'],axis=1)

# %%
df2 = df2.drop(['rank'],axis=1)

# %%
df2
# Out:
#     release_date                                        title  \
# 0     2019-04-23                            Avengers: Endgame
# 1     2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2     2015-04-22                      Avengers: Age of Ultron
# 3     2015-12-16         Star Wars Ep. VII: The Force Awakens
# 4     2018-04-25                       Avengers: Infinity War
# ..           ...                                          ...
# 495   2013-02-06                       A Good Day to Die Hard
# 496   2004-04-09                                    The Alamo
# 497   1995-12-22                             Cutthroat Island
# 498   2013-12-19              The Secret Life of Walter Mitty
# 499   2023-03-09                                           65
#
#      production_cost  domestic_gross  worldwide_gross  opening_weekend   mpaa  \
# 0          400000000       858373000       2797800564      357115007.0  PG-13
# ...

# %%
df2.isnull() == True
# Out:
#      release_date  title  production_cost  domestic_gross  worldwide_gross  \
# 0           False  False            False           False            False
# 1           False  False            False           False            False
# 2           False  False            False           False            False
# 3           False  False            False           False            False
# 4           False  False            False           False            False
# ..            ...    ...              ...             ...              ...
# 495         False  False            False           False            False
# 496         False  False            False           False            False
# 497         False  False            False           False            False
# 498         False  False            False           False            False
# 499         False  False            False           False            False
#
#      opening_weekend   mpaa  genre  theaters  runtime   year
# ...

# %%
df2 = df2.fillna(0)

# %%
df2.isnull()
# Out:
#      release_date  title  production_cost  domestic_gross  worldwide_gross  \
# 0           False  False            False           False            False
# 1           False  False            False           False            False
# 2           False  False            False           False            False
# 3           False  False            False           False            False
# 4           False  False            False           False            False
# ..            ...    ...              ...             ...              ...
# 495         False  False            False           False            False
# 496         False  False            False           False            False
# 497         False  False            False           False            False
# 498         False  False            False           False            False
# 499         False  False            False           False            False
#
#      opening_weekend   mpaa  genre  theaters  runtime   year
# ...

# %%
df2
# Out:
#     release_date                                        title  \
# 0     2019-04-23                            Avengers: Endgame
# 1     2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2     2015-04-22                      Avengers: Age of Ultron
# 3     2015-12-16         Star Wars Ep. VII: The Force Awakens
# 4     2018-04-25                       Avengers: Infinity War
# ..           ...                                          ...
# 495   2013-02-06                       A Good Day to Die Hard
# 496   2004-04-09                                    The Alamo
# 497   1995-12-22                             Cutthroat Island
# 498   2013-12-19              The Secret Life of Walter Mitty
# 499   2023-03-09                                           65
#
#      production_cost  domestic_gross  worldwide_gross  opening_weekend   mpaa  \
# 0          400000000       858373000       2797800564      357115007.0  PG-13
# ...

# %%
df2['Profit'] = df2['domestic_gross'] - df2['production_cost']
df2
# Out:
#     release_date                                        title  \
# 0     2019-04-23                            Avengers: Endgame
# 1     2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2     2015-04-22                      Avengers: Age of Ultron
# 3     2015-12-16         Star Wars Ep. VII: The Force Awakens
# 4     2018-04-25                       Avengers: Infinity War
# ..           ...                                          ...
# 495   2013-02-06                       A Good Day to Die Hard
# 496   2004-04-09                                    The Alamo
# 497   1995-12-22                             Cutthroat Island
# 498   2013-12-19              The Secret Life of Walter Mitty
# 499   2023-03-09                                           65
#
#      production_cost  domestic_gross  worldwide_gross  opening_weekend   mpaa  \
# 0          400000000       858373000       2797800564      357115007.0  PG-13
# ...

# %%
df2 = df2.drop(['production_cost'], axis=1)

# %%
df2 = df2.drop(['domestic_gross'],axis =1)

# %%
df2
# Out:
#     release_date                                        title  \
# 0     2019-04-23                            Avengers: Endgame
# 1     2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2     2015-04-22                      Avengers: Age of Ultron
# 3     2015-12-16         Star Wars Ep. VII: The Force Awakens
# 4     2018-04-25                       Avengers: Infinity War
# ..           ...                                          ...
# 495   2013-02-06                       A Good Day to Die Hard
# 496   2004-04-09                                    The Alamo
# 497   1995-12-22                             Cutthroat Island
# 498   2013-12-19              The Secret Life of Walter Mitty
# 499   2023-03-09                                           65
#
#      worldwide_gross  opening_weekend   mpaa              genre  theaters  \
# 0         2797800564      357115007.0  PG-13             Action    4662.0
# ...

# %%
df2['Profit'] = df2['Profit']+df2['worldwide_gross']
df2
# Out:
#     release_date                                        title  \
# 0     2019-04-23                            Avengers: Endgame
# 1     2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2     2015-04-22                      Avengers: Age of Ultron
# 3     2015-12-16         Star Wars Ep. VII: The Force Awakens
# 4     2018-04-25                       Avengers: Infinity War
# ..           ...                                          ...
# 495   2013-02-06                       A Good Day to Die Hard
# 496   2004-04-09                                    The Alamo
# 497   1995-12-22                             Cutthroat Island
# 498   2013-12-19              The Secret Life of Walter Mitty
# 499   2023-03-09                                           65
#
#      worldwide_gross  opening_weekend   mpaa              genre  theaters  \
# 0         2797800564      357115007.0  PG-13             Action    4662.0
# ...

# %%
df2 = df2.drop(['worldwide_gross'],axis =1)

# %%
df2
# Out:
#     release_date                                        title  \
# 0     2019-04-23                            Avengers: Endgame
# 1     2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2     2015-04-22                      Avengers: Age of Ultron
# 3     2015-12-16         Star Wars Ep. VII: The Force Awakens
# 4     2018-04-25                       Avengers: Infinity War
# ..           ...                                          ...
# 495   2013-02-06                       A Good Day to Die Hard
# 496   2004-04-09                                    The Alamo
# 497   1995-12-22                             Cutthroat Island
# 498   2013-12-19              The Secret Life of Walter Mitty
# 499   2023-03-09                                           65
#
#      opening_weekend   mpaa              genre  theaters  runtime    year  \
# 0        357115007.0  PG-13             Action    4662.0    181.0  2019.0
# ...

# %%
np.unique(df2.runtime)
# Out:
# array([  0.,  76.,  77.,  78.,  82.,  85.,  86.,  87.,  88.,  89.,  90.,
#         91.,  92.,  93.,  94.,  95.,  96.,  97.,  98.,  99., 100., 101.,
#        102., 103., 104., 105., 106., 107., 108., 109., 110., 111., 112.,
#        113., 114., 115., 116., 117., 118., 119., 120., 121., 122., 123.,
#        124., 125., 126., 127., 128., 129., 130., 131., 132., 133., 134.,
#        135., 136., 137., 138., 139., 140., 141., 142., 143., 144., 145.,
#        146., 147., 148., 149., 150., 151., 152., 153., 154., 155., 156.,
#        157., 158., 161., 162., 163., 164., 165., 167., 169., 170., 172.,
#        175., 179., 181., 182., 189., 194., 201., 210.])

# %%
df2.loc[(df2['runtime'] == 0),'runtime']= df2['runtime'].mean()

# %%
np.unique(df['runtime'])
# Out:
# array([ 76.,  77.,  78.,  82.,  85.,  86.,  87.,  88.,  89.,  90.,  91.,
#         92.,  93.,  94.,  95.,  96.,  97.,  98.,  99., 100., 101., 102.,
#        103., 104., 105., 106., 107., 108., 109., 110., 111., 112., 113.,
#        114., 115., 116., 117., 118., 119., 120., 121., 122., 123., 124.,
#        125., 126., 127., 128., 129., 130., 131., 132., 133., 134., 135.,
#        136., 137., 138., 139., 140., 141., 142., 143., 144., 145., 146.,
#        147., 148., 149., 150., 151., 152., 153., 154., 155., 156., 157.,
#        158., 161., 162., 163., 164., 165., 167., 169., 170., 172., 175.,
#        179., 181., 182., 189., 194., 201., 210.,  nan])

# %%
np.isnan(df2['runtime'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Name: runtime, Length: 500, dtype: bool

# %%
df2['runtime'].isnull().sum()
# Out:
# 0

# %%
np.unique(df2.runtime)
# Out:
# array([ 76.   ,  77.   ,  78.   ,  82.   ,  85.   ,  86.   ,  87.   ,
#         88.   ,  89.   ,  90.   ,  91.   ,  92.   ,  93.   ,  94.   ,
#         95.   ,  96.   ,  97.   ,  98.   ,  99.   , 100.   , 101.   ,
#        102.   , 103.   , 104.   , 105.   , 106.   , 107.   , 108.   ,
#        109.   , 110.   , 111.   , 112.   , 113.   , 114.   , 115.   ,
#        116.   , 117.   , 118.   , 118.716, 119.   , 120.   , 121.   ,
#        122.   , 123.   , 124.   , 125.   , 126.   , 127.   , 128.   ,
#        129.   , 130.   , 131.   , 132.   , 133.   , 134.   , 135.   ,
#        136.   , 137.   , 138.   , 139.   , 140.   , 141.   , 142.   ,
#        143.   , 144.   , 145.   , 146.   , 147.   , 148.   , 149.   ,
#        150.   , 151.   , 152.   , 153.   , 154.   , 155.   , 156.   ,
#        157.   , 158.   , 161.   , 162.   , 163.   , 164.   , 165.   ,
#        167.   , 169.   , 170.   , 172.   , 175.   , 179.   , 181.   ,
#        182.   , 189.   , 194.   , 201.   , 210.   ])

# %%
df2['runtime'] = df2['runtime'].astype(int)

# %%
np.unique(df2.runtime)
# Out:
# array([ 76,  77,  78,  82,  85,  86,  87,  88,  89,  90,  91,  92,  93,
#         94,  95,  96,  97,  98,  99, 100, 101, 102, 103, 104, 105, 106,
#        107, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 119,
#        120, 121, 122, 123, 124, 125, 126, 127, 128, 129, 130, 131, 132,
#        133, 134, 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145,
#        146, 147, 148, 149, 150, 151, 152, 153, 154, 155, 156, 157, 158,
#        161, 162, 163, 164, 165, 167, 169, 170, 172, 175, 179, 181, 182,
#        189, 194, 201, 210])

# %%
df2['release_date'] = pd.to_datetime(df2['release_date'])

# %%
df2['Year']= df2['release_date'].dt.year

# %%
df2
# Out:
#     release_date                                        title  \
# 0     2019-04-23                            Avengers: Endgame
# 1     2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2     2015-04-22                      Avengers: Age of Ultron
# 3     2015-12-16         Star Wars Ep. VII: The Force Awakens
# 4     2018-04-25                       Avengers: Infinity War
# ..           ...                                          ...
# 495   2013-02-06                       A Good Day to Die Hard
# 496   2004-04-09                                    The Alamo
# 497   1995-12-22                             Cutthroat Island
# 498   2013-12-19              The Secret Life of Walter Mitty
# 499   2023-03-09                                           65
#
#      opening_weekend   mpaa              genre  theaters  runtime    year  \
# 0        357115007.0  PG-13             Action    4662.0      181  2019.0
# ...

# %%
df2 = df2.drop(['year'],axis =1)

# %%
df2
# Out:
#     release_date                                        title  \
# 0     2019-04-23                            Avengers: Endgame
# 1     2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2     2015-04-22                      Avengers: Age of Ultron
# 3     2015-12-16         Star Wars Ep. VII: The Force Awakens
# 4     2018-04-25                       Avengers: Infinity War
# ..           ...                                          ...
# 495   2013-02-06                       A Good Day to Die Hard
# 496   2004-04-09                                    The Alamo
# 497   1995-12-22                             Cutthroat Island
# 498   2013-12-19              The Secret Life of Walter Mitty
# 499   2023-03-09                                           65
#
#      opening_weekend   mpaa              genre  theaters  runtime      Profit  \
# 0        357115007.0  PG-13             Action    4662.0      181  3256173564
# ...

# %%
df2 = df2.drop(['release_date'],axis =1)
df2
# Out:
#                                            title  opening_weekend   mpaa  \
# 0                              Avengers: Endgame      357115007.0  PG-13
# 1    Pirates of the Caribbean: On Stranger Tides       90151958.0  PG-13
# 2                        Avengers: Age of Ultron      191271109.0  PG-13
# 3           Star Wars Ep. VII: The Force Awakens      247966675.0  PG-13
# 4                         Avengers: Infinity War      257698183.0  PG-13
# ..                                           ...              ...    ...
# 495                       A Good Day to Die Hard       24834845.0      R
# 496                                    The Alamo        9124701.0  PG-13
# 497                             Cutthroat Island        2371415.0  PG-13
# 498              The Secret Life of Walter Mitty       12765508.0     PG
# 499                                           65              0.0      0
#
#                  genre  theaters  runtime      Profit  Year
# ...

# %%
df2.loc[(df2['theaters'] == 0),'theaters']= df2['theaters'].mean()

# %%
np.unique(df2['theaters'])
# Out:
# array([  30.  , 1619.  , 1920.  , 2023.  , 2132.  , 2218.  , 2222.  ,
#        2313.  , 2320.  , 2340.  , 2420.  , 2445.  , 2483.  , 2495.  ,
#        2500.  , 2521.  , 2530.  , 2556.  , 2557.  , 2561.  , 2608.  ,
#        2609.  , 2625.  , 2638.  , 2649.  , 2665.  , 2690.  , 2721.  ,
#        2756.  , 2759.  , 2761.  , 2801.  , 2807.  , 2813.  , 2820.  ,
#        2835.  , 2852.  , 2875.  , 2887.  , 2893.  , 2898.  , 2910.  ,
#        2922.  , 2930.  , 2938.  , 2942.  , 2946.  , 2966.  , 2971.  ,
#        2988.  , 2996.  , 3001.  , 3004.  , 3012.  , 3026.  , 3030.  ,
#        3057.  , 3058.  , 3061.  , 3065.  , 3077.  , 3084.  , 3087.  ,
#        3089.  , 3101.  , 3103.  , 3104.  , 3111.  , 3117.  , 3119.  ,
#        3126.  , 3131.  , 3138.  , 3143.  , 3151.  , 3160.  , 3161.  ,
#        3165.  , 3180.  , 3184.  , 3188.  , 3200.  , 3202.  , 3203.  ,
#        3219.  , 3221.  , 3222.  , 3223.  , 3227.  , 3239.  , 3242.  ,
# ...

# %%
df2['theaters'] = df2['theaters'].astype(int)

# %%
df2
# Out:
#                                            title  opening_weekend   mpaa  \
# 0                              Avengers: Endgame      357115007.0  PG-13
# 1    Pirates of the Caribbean: On Stranger Tides       90151958.0  PG-13
# 2                        Avengers: Age of Ultron      191271109.0  PG-13
# 3           Star Wars Ep. VII: The Force Awakens      247966675.0  PG-13
# 4                         Avengers: Infinity War      257698183.0  PG-13
# ..                                           ...              ...    ...
# 495                       A Good Day to Die Hard       24834845.0      R
# 496                                    The Alamo        9124701.0  PG-13
# 497                             Cutthroat Island        2371415.0  PG-13
# 498              The Secret Life of Walter Mitty       12765508.0     PG
# 499                                           65              0.0      0
#
#                  genre  theaters  runtime      Profit  Year
# ...

# %%
df2.loc[(df2['opening_weekend'] == 0),'opening_weekend']= df2['opening_weekend'].mean()

# %%
np.unique(df2['opening_weekend'])
# Out:
# array([4.85580000e+04, 1.16616000e+05, 1.79823000e+05, 2.43390000e+05,
#        4.74560000e+05, 5.76216000e+05, 7.86190000e+05, 8.58021000e+05,
#        2.18290000e+06, 2.37141500e+06, 3.02985800e+06, 3.77535000e+06,
#        4.75915100e+06, 5.91554200e+06, 6.30769100e+06, 6.61987000e+06,
#        6.91448800e+06, 7.21764000e+06, 7.48469600e+06, 7.51167500e+06,
#        7.55985000e+06, 7.57613200e+06, 8.64832400e+06, 9.12470100e+06,
#        9.49687000e+06, 9.61224700e+06, 9.72099300e+06, 9.80025200e+06,
#        9.81230200e+06, 9.86899700e+06, 9.91031000e+06, 1.02677560e+07,
#        1.02782250e+07, 1.05746180e+07, 1.07490110e+07, 1.08863860e+07,
#        1.09507050e+07, 1.10533660e+07, 1.11394950e+07, 1.12038150e+07,
#        1.13645050e+07, 1.14088530e+07, 1.20832480e+07, 1.24090700e+07,
#        1.26914150e+07, 1.27017430e+07, 1.27655080e+07, 1.27852040e+07,
#        1.28466520e+07, 1.32515450e+07, 1.33547980e+07, 1.34015860e+07,
# ...

# %%
df2.to_csv('movies_tableau.csv')
